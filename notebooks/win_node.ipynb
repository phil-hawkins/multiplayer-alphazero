# %%
import sys, os; sys.path.insert(1, os.path.join(sys.path[0], '..'))
from hex.graph_hex_board import GraphHexBoard
import numpy as np
import torch
from matplotlib.cm import ScalarMappable

class GHB(GraphHexBoard):
    @property
    def cell_colours(self):
        sm = ScalarMappable(cmap='viridis')
        return sm.to_rgba(self.x)

class AverageMeter(object):
    def __init__(self):
        self.val = 0.
        self.avg = 0.
        self.sum = 0.
        self.count = 0.

    def __repr__(self):
        return f'{self.avg:.2e}'

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
from itertools import combinations, product

def secure_2hop(n_nodes, A, edge_index, side_n):
    # label the secure 2 hop faces
    y = torch.zeros(n_nodes)
    y[side_n] = 1.
    m = edge_index[0] == side_n
    one_hop = edge_index[1, m]
    y = A @ (A @ y)
    y[side_n] = 0.
    y[one_hop] = 0.

    return (y >= 2.).nonzero().squeeze().tolist()

def independent_s2h_pairs(s_2hop, edge_index, side_n):
    # get the side connection sets for each 2-hop side connections
    csets = {}
    for n in s_2hop:
        a = set(edge_index[1, edge_index[0] == n].tolist())
        b = set(edge_index[1, edge_index[0] == side_n].tolist())
        csets[n] = a & b

    pset = combinations(s_2hop, 2)

    #find independent pairs of secure 2-hop side connections 
    i2hsc = []
    for s in pset:
        a, b = csets[s[0]], csets[s[1]]
        ndups = len(a & b)
        if (len(a) + len(b) - ndups) >= 4:
            i2hsc.append(s)
    
    return i2hsc

def find_winner(ns):
    n_nodes = ns**2 + 4
    l_side = n_nodes - 2
    r_side = n_nodes - 1
    # setup the board
    board = GHB.new_vortex_board(ns)
    A = torch.sparse_coo_tensor(board.edge_index, torch.ones_like(board.edge_index[0]), dtype=torch.float)
    edge_index = board.edge_index

    board.x = torch.zeros(n_nodes)
    ls_2hop = secure_2hop(n_nodes, A, edge_index, l_side)
    rs_2hop = secure_2hop(n_nodes, A, edge_index, r_side)
    board.x[ls_2hop + rs_2hop] = 1.

    lsp = independent_s2h_pairs(ls_2hop, edge_index, l_side)
    rsp = independent_s2h_pairs(rs_2hop, edge_index, r_side)
    opp_pairs = product(lsp, rsp)

    def connectors(A, ndx):
        return (A.to_dense()[ndx].sum(dim=0) == len(ndx)).nonzero().squeeze()

    for scn in opp_pairs:
        ndx = list(scn[0]) + list(scn[1])
        cn = connectors(A, ndx)
        if cn.numel() == 1:
            return board, cn.item()

    return None


ns = 5
res = None
while(res is None):
    res = find_winner(ns)

board, n = res
board.x = torch.zeros_like(board.node_attr[:,0])
board.x[n] = 1.
board.plot()

# %%
from torch.utils.data import TensorDataset
from torch_geometric.utils import get_laplacian

def wi8_features(ns, edge_index, dim):    
    n_nodes = ns**2 + 4
    l_side = n_nodes - 2
    r_side = n_nodes - 1

    L = get_laplacian(edge_index, normalization='sym')
    L = torch.sparse_coo_tensor(L[0], L[1])

    # features
    n_steps = dim // 2
    steps = []

    x = torch.zeros_like(board.node_attr[:,0])
    x[l_side] = 1.
    for i in range(n_steps):
        steps.append(x.clone().detach())
        if i < n_steps-1:
            x = L @ x

    x = torch.zeros_like(board.node_attr[:,0])
    x[r_side] = 1.
    for i in range(n_steps):
        steps.append(x.clone().detach())
        if i < n_steps-1:
            x = L @ x

    x = torch.stack(steps, dim=1)
    
    return x


def get_wi8(ns):   
    res = None
    while(res is None):
        res = find_winner(ns)
    return res 

class WI8_DS(TensorDataset):
    def __init__(self, sample_boards=1000, nsides=5, dim=20):   
        self.sample_boards = sample_boards
        self.nsides = nsides
        self.dim = dim

        x, y = [], []

        for i in range(sample_boards):
            board, n = get_wi8(nsides)
            xs = wi8_features(nsides, board.edge_index, dim)
            x.append(xs)
            y.append(n)

        x = torch.stack(x, dim=0)
        y = torch.tensor(y, dtype=torch.long)
        super().__init__(x, y)


class WI8Raw_DS(TensorDataset):
    def __init__(self, sample_boards=1000, nsides=5, dim=20):   
        self.sample_boards = sample_boards
        self.nsides = nsides
        self.dim = dim
        n_nodes = nsides**2 + 4
        l_side = n_nodes - 2
        r_side = n_nodes - 1

        x, y, edge_index = [], [], []

        for i in range(sample_boards):
            board, n = get_wi8(nsides)
            xs = torch.zeros(n_nodes, 2)
            xs[l_side, 0] = 1.
            xs[r_side, 1] = 1.
            x.append(xs)
            y.append(n)
            edge_index.append(board.edge_index)

        x = torch.stack(x, dim=0)
        y = torch.tensor(y, dtype=torch.long)
        edge_index = torch.stack(edge_index, dim=0)
        super().__init__(x, y, edge_index)

# %%
nsides=5
dim=20

# train_ds = WI8_DS(sample_boards=2000, nsides=nsides, dim=dim)
# val_ds = WI8_DS(sample_boards=200, nsides=nsides, dim=dim)

train_ds = WI8Raw_DS(sample_boards=2000, nsides=nsides, dim=dim)
val_ds = WI8Raw_DS(sample_boards=200, nsides=nsides, dim=dim)

# %%
from torch.nn import Linear, Module, LogSoftmax, Softmax
from torch_geometric.nn import ChebConv

class VorNet_MLP(Module):
    """
    top-1 accuracy 98.44% on 25 node board
    """
    def __init__(self, in_features=20):
        super().__init__()
        self.lin1 = Linear(in_features=in_features, out_features=64)
        self.lin2 = Linear(in_features=64, out_features=1)
        self.train_readout = LogSoftmax(dim=1)
        self.readout = Softmax(dim=1)

    def forward(self, x):
        B, N, F = x.shape

        x = x.view(B*N, F)
        x = self.lin1(x)
        x = x.relu()
        out = self.lin2(x)
        
        out = out.view(B, N)
        readout = self.train_readout if self.training else self.readout
        out = readout(out)

        return out

class VorNet_Cheb(Module):
    """
    top-1 accuracy 98.83% on 25 node board
    """
    def __init__(self):
        super().__init__()
        self.cheb = ChebConv(in_channels=2, out_channels=64, K=10, normalization='sym')
        self.lin = Linear(in_features=64, out_features=1)
        self.train_readout = LogSoftmax(dim=1)
        self.readout = Softmax(dim=1)

    def forward(self, x, edge_index):
        B, N, F = x.shape
        edge_index_batch = torch.arange(start=0, end=B*N, step=N, device=x.device)
        edge_index_batch = edge_index_batch.view(-1,1,1).expand_as(edge_index)
        edge_index += edge_index_batch
        edge_index = edge_index.permute(1,0,2).reshape(2, -1)
        x = x.view(B*N, F)

        x = self.cheb(x, edge_index)
        x = x.relu()
        out = self.lin(x)
        
        out = out.view(B, N)
        readout = self.train_readout if self.training else self.readout
        out = readout(out)

        return out

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = VorNet_Cheb().to(device)

# %%
from torch.utils.data import DataLoader
from torch.nn import NLLLoss
from sklearn.metrics import top_k_accuracy_score

LR = 1e-4
EPOCHS = 10000
BATCH_SIZE = 64

criterion = NLLLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LR)
train_dl = DataLoader(train_ds, batch_size=BATCH_SIZE)
val_dl = DataLoader(val_ds, batch_size=BATCH_SIZE)

for epoch in range(EPOCHS):
    train_loss = AverageMeter()
    val_loss = AverageMeter()
    val_accuracy = AverageMeter()
    print("Epoch {}".format(epoch))

    model.train()
    for x, y, edge_index in train_dl:
        x, y, edge_index = x.to(device=device), y.to(device=device), edge_index.to(device=device)
        out = model(x, edge_index)
        loss = criterion(out, y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_loss.update(loss.item())
    
    print("\ttrain - loss: {}".format(train_loss))

    model.eval()
    with torch.no_grad():
        for x, y, edge_index in val_dl:
            x, y, edge_index = x.to(device=device), y.to(device=device), edge_index.to(device=device)
            out = model(x, edge_index)
            loss = criterion(out, y)
            val_loss.update(loss.item())
            val_accuracy.update(top_k_accuracy_score(y.cpu().numpy(), out.squeeze().cpu().numpy(), k=1, labels=np.arange(29)))

    print("\tval - loss: {}, accuracy: {:.2f}%".format(val_loss.avg, val_accuracy.avg*100))
# Out:
# Epoch 0
# 	train - loss: 3.33e+00
# 	val - loss: -0.03610346466302872, accuracy: 44.53%
# Epoch 1
# 	train - loss: 3.31e+00
# 	val - loss: -0.036891547963023186, accuracy: 55.08%
# Epoch 2
# 	train - loss: 3.29e+00
# 	val - loss: -0.03772658109664917, accuracy: 58.20%
# Epoch 3
# 	train - loss: 3.26e+00
# 	val - loss: -0.03862486779689789, accuracy: 58.20%
# Epoch 4
# 	train - loss: 3.24e+00
# 	val - loss: -0.039595507085323334, accuracy: 57.81%
# Epoch 5
# 	train - loss: 3.21e+00
# 	val - loss: -0.04065823741257191, accuracy: 58.20%
# Epoch 6
# 	train - loss: 3.19e+00
# 	val - loss: -0.04183006752282381, accuracy: 58.59%
# Epoch 7
# 	train - loss: 3.16e+00
# 	val - loss: -0.04312863200902939, accuracy: 58.20%
# Epoch 8
# 	train - loss: 3.13e+00
# 	val - loss: -0.044568903744220734, accuracy: 58.20%
# Epoch 9
# 	train - loss: 3.09e+00
# 	val - loss: -0.04616723861545324, accuracy: 58.20%
# Epoch 10
# 	train - loss: 3.06e+00
# 	val - loss: -0.04793732054531574, accuracy: 57.42%
# Epoch 11
# 	train - loss: 3.02e+00
# 	val - loss: -0.04989252891391516, accuracy: 57.42%
# Epoch 12
# 	train - loss: 2.98e+00
# 	val - loss: -0.052046422846615314, accuracy: 57.42%
# Epoch 13
# 	train - loss: 2.93e+00
# 	val - loss: -0.054417517967522144, accuracy: 57.42%
# Epoch 14
# 	train - loss: 2.89e+00
# 	val - loss: -0.05702186096459627, accuracy: 57.03%
# Epoch 15
# 	train - loss: 2.84e+00
# 	val - loss: -0.059873114340007305, accuracy: 57.03%
# Epoch 16
# 	train - loss: 2.79e+00
# 	val - loss: -0.06299835909157991, accuracy: 57.03%
# Epoch 17
# 	train - loss: 2.74e+00
# 	val - loss: -0.06640691868960857, accuracy: 57.03%
# Epoch 18
# 	train - loss: 2.69e+00
# 	val - loss: -0.07013702392578125, accuracy: 57.42%
# Epoch 19
# 	train - loss: 2.63e+00
# 	val - loss: -0.07419199869036674, accuracy: 57.81%
# Epoch 20
# 	train - loss: 2.58e+00
# 	val - loss: -0.07860148139297962, accuracy: 57.42%
# Epoch 21
# 	train - loss: 2.52e+00
# 	val - loss: -0.08337455056607723, accuracy: 57.03%
# Epoch 22
# 	train - loss: 2.47e+00
# 	val - loss: -0.08852960355579853, accuracy: 57.03%
# Epoch 23
# 	train - loss: 2.41e+00
# 	val - loss: -0.09406193159520626, accuracy: 57.03%
# Epoch 24
# 	train - loss: 2.35e+00
# 	val - loss: -0.0999999288469553, accuracy: 57.03%
# Epoch 25
# 	train - loss: 2.29e+00
# 	val - loss: -0.10632172785699368, accuracy: 57.03%
# Epoch 26
# 	train - loss: 2.23e+00
# 	val - loss: -0.11303776688873768, accuracy: 56.64%
# Epoch 27
# 	train - loss: 2.17e+00
# 	val - loss: -0.12014121562242508, accuracy: 56.64%
# Epoch 28
# 	train - loss: 2.12e+00
# 	val - loss: -0.1276160292327404, accuracy: 56.64%
# Epoch 29
# 	train - loss: 2.06e+00
# 	val - loss: -0.1354210563004017, accuracy: 57.03%
# Epoch 30
# 	train - loss: 2.01e+00
# 	val - loss: -0.14357494190335274, accuracy: 57.42%
# Epoch 31
# 	train - loss: 1.95e+00
# 	val - loss: -0.15200255066156387, accuracy: 57.42%
# Epoch 32
# 	train - loss: 1.90e+00
# 	val - loss: -0.1606917828321457, accuracy: 57.03%
# Epoch 33
# 	train - loss: 1.85e+00
# 	val - loss: -0.16958165168762207, accuracy: 57.03%
# Epoch 34
# 	train - loss: 1.80e+00
# 	val - loss: -0.17864253744482994, accuracy: 57.03%
# Epoch 35
# 	train - loss: 1.75e+00
# 	val - loss: -0.18781403079628944, accuracy: 57.03%
# Epoch 36
# 	train - loss: 1.71e+00
# 	val - loss: -0.19702307879924774, accuracy: 57.03%
# Epoch 37
# 	train - loss: 1.67e+00
# 	val - loss: -0.20631398260593414, accuracy: 57.03%
# Epoch 38
# 	train - loss: 1.63e+00
# 	val - loss: -0.21559473872184753, accuracy: 57.03%
# Epoch 39
# 	train - loss: 1.59e+00
# 	val - loss: -0.22482184320688248, accuracy: 57.42%
# Epoch 40
# 	train - loss: 1.55e+00
# 	val - loss: -0.2339506484568119, accuracy: 57.42%
# Epoch 41
# 	train - loss: 1.52e+00
# 	val - loss: -0.24299237504601479, accuracy: 57.42%
# Epoch 42
# 	train - loss: 1.48e+00
# 	val - loss: -0.25191862136125565, accuracy: 57.42%
# Epoch 43
# 	train - loss: 1.45e+00
# 	val - loss: -0.26067162305116653, accuracy: 57.42%
# Epoch 44
# 	train - loss: 1.42e+00
# 	val - loss: -0.2692412808537483, accuracy: 57.42%
# Epoch 45
# 	train - loss: 1.40e+00
# 	val - loss: -0.2776448130607605, accuracy: 57.42%
# Epoch 46
# 	train - loss: 1.37e+00
# 	val - loss: -0.2858489826321602, accuracy: 57.42%
# Epoch 47
# 	train - loss: 1.34e+00
# 	val - loss: -0.2938479855656624, accuracy: 57.42%
# Epoch 48
# 	train - loss: 1.32e+00
# 	val - loss: -0.30165768414735794, accuracy: 57.03%
# Epoch 49
# 	train - loss: 1.30e+00
# 	val - loss: -0.3092893436551094, accuracy: 57.03%
# Epoch 50
# 	train - loss: 1.28e+00
# 	val - loss: -0.31666339188814163, accuracy: 57.03%
# Epoch 51
# 	train - loss: 1.26e+00
# 	val - loss: -0.32394054532051086, accuracy: 57.42%
# Epoch 52
# 	train - loss: 1.24e+00
# 	val - loss: -0.3309650719165802, accuracy: 57.42%
# Epoch 53
# 	train - loss: 1.22e+00
# 	val - loss: -0.3377560004591942, accuracy: 57.42%
# Epoch 54
# 	train - loss: 1.20e+00
# 	val - loss: -0.3443716838955879, accuracy: 57.81%
# Epoch 55
# 	train - loss: 1.19e+00
# 	val - loss: -0.3507622331380844, accuracy: 58.20%
# Epoch 56
# 	train - loss: 1.17e+00
# 	val - loss: -0.3569803237915039, accuracy: 58.20%
# Epoch 57
# 	train - loss: 1.16e+00
# 	val - loss: -0.36297983676195145, accuracy: 58.59%
# Epoch 58
# 	train - loss: 1.14e+00
# 	val - loss: -0.36881273239851, accuracy: 58.98%
# Epoch 59
# 	train - loss: 1.13e+00
# 	val - loss: -0.37444865703582764, accuracy: 59.38%
# Epoch 60
# 	train - loss: 1.12e+00
# 	val - loss: -0.37989795207977295, accuracy: 59.38%
# Epoch 61
# 	train - loss: 1.10e+00
# 	val - loss: -0.38520409166812897, accuracy: 59.38%
# Epoch 62
# 	train - loss: 1.09e+00
# 	val - loss: -0.3903292715549469, accuracy: 59.38%
# Epoch 63
# 	train - loss: 1.08e+00
# 	val - loss: -0.3953009992837906, accuracy: 59.38%
# Epoch 64
# 	train - loss: 1.07e+00
# 	val - loss: -0.4001196250319481, accuracy: 62.50%
# Epoch 65
# 	train - loss: 1.06e+00
# 	val - loss: -0.4047969654202461, accuracy: 62.89%
# Epoch 66
# 	train - loss: 1.05e+00
# 	val - loss: -0.4093391001224518, accuracy: 62.89%
# Epoch 67
# 	train - loss: 1.04e+00
# 	val - loss: -0.41373735666275024, accuracy: 62.89%
# Epoch 68
# 	train - loss: 1.03e+00
# 	val - loss: -0.4179986044764519, accuracy: 66.41%
# Epoch 69
# 	train - loss: 1.02e+00
# 	val - loss: -0.422166645526886, accuracy: 66.41%
# Epoch 70
# 	train - loss: 1.01e+00
# 	val - loss: -0.426254004240036, accuracy: 66.41%
# Epoch 71
# 	train - loss: 1.00e+00
# 	val - loss: -0.43023741245269775, accuracy: 66.41%
# Epoch 72
# 	train - loss: 9.93e-01
# 	val - loss: -0.4341057762503624, accuracy: 66.41%
# Epoch 73
# 	train - loss: 9.84e-01
# 	val - loss: -0.4378713071346283, accuracy: 66.80%
# Epoch 74
# 	train - loss: 9.76e-01
# 	val - loss: -0.4415665790438652, accuracy: 66.80%
# Epoch 75
# 	train - loss: 9.69e-01
# 	val - loss: -0.4451388120651245, accuracy: 66.80%
# Epoch 76
# 	train - loss: 9.61e-01
# 	val - loss: -0.44864752888679504, accuracy: 67.58%
# Epoch 77
# 	train - loss: 9.54e-01
# 	val - loss: -0.4520816281437874, accuracy: 67.58%
# Epoch 78
# 	train - loss: 9.46e-01
# 	val - loss: -0.45546892285346985, accuracy: 67.97%
# Epoch 79
# 	train - loss: 9.39e-01
# 	val - loss: -0.4587354511022568, accuracy: 67.97%
# Epoch 80
# 	train - loss: 9.32e-01
# 	val - loss: -0.46198198199272156, accuracy: 67.97%
# Epoch 81
# 	train - loss: 9.25e-01
# 	val - loss: -0.4651425629854202, accuracy: 68.36%
# Epoch 82
# 	train - loss: 9.19e-01
# 	val - loss: -0.4682636111974716, accuracy: 68.36%
# Epoch 83
# 	train - loss: 9.12e-01
# 	val - loss: -0.47128649801015854, accuracy: 68.75%
# Epoch 84
# 	train - loss: 9.06e-01
# 	val - loss: -0.47427869588136673, accuracy: 68.75%
# Epoch 85
# 	train - loss: 9.00e-01
# 	val - loss: -0.4772261083126068, accuracy: 68.75%
# Epoch 86
# 	train - loss: 8.93e-01
# 	val - loss: -0.4801226407289505, accuracy: 69.14%
# Epoch 87
# 	train - loss: 8.87e-01
# 	val - loss: -0.4829550012946129, accuracy: 69.14%
# Epoch 88
# 	train - loss: 8.81e-01
# 	val - loss: -0.4857388734817505, accuracy: 69.53%
# Epoch 89
# 	train - loss: 8.75e-01
# 	val - loss: -0.48848460614681244, accuracy: 69.53%
# Epoch 90
# 	train - loss: 8.70e-01
# 	val - loss: -0.4911698251962662, accuracy: 69.53%
# Epoch 91
# 	train - loss: 8.64e-01
# 	val - loss: -0.49384840577840805, accuracy: 69.53%
# Epoch 92
# 	train - loss: 8.58e-01
# 	val - loss: -0.4964708313345909, accuracy: 69.53%
# Epoch 93
# 	train - loss: 8.53e-01
# 	val - loss: -0.49905527383089066, accuracy: 69.53%
# Epoch 94
# 	train - loss: 8.47e-01
# 	val - loss: -0.5016013011336327, accuracy: 70.31%
# Epoch 95
# 	train - loss: 8.42e-01
# 	val - loss: -0.5041146948933601, accuracy: 70.31%
# Epoch 96
# 	train - loss: 8.37e-01
# 	val - loss: -0.5066012218594551, accuracy: 70.31%
# Epoch 97
# 	train - loss: 8.31e-01
# 	val - loss: -0.5090207308530807, accuracy: 70.31%
# Epoch 98
# 	train - loss: 8.26e-01
# 	val - loss: -0.5114396065473557, accuracy: 70.70%
# Epoch 99
# 	train - loss: 8.21e-01
# 	val - loss: -0.5138073191046715, accuracy: 71.48%
# Epoch 100
# 	train - loss: 8.16e-01
# 	val - loss: -0.5161698758602142, accuracy: 71.88%
# Epoch 101
# 	train - loss: 8.11e-01
# 	val - loss: -0.5184849500656128, accuracy: 71.88%
# Epoch 102
# 	train - loss: 8.06e-01
# 	val - loss: -0.520797073841095, accuracy: 71.88%
# Epoch 103
# 	train - loss: 8.01e-01
# 	val - loss: -0.5230373293161392, accuracy: 71.88%
# Epoch 104
# 	train - loss: 7.97e-01
# 	val - loss: -0.5252981036901474, accuracy: 71.88%
# Epoch 105
# 	train - loss: 7.92e-01
# 	val - loss: -0.5275258868932724, accuracy: 71.88%
# Epoch 106
# 	train - loss: 7.87e-01
# 	val - loss: -0.5297190248966217, accuracy: 72.27%
# Epoch 107
# 	train - loss: 7.82e-01
# 	val - loss: -0.5318920314311981, accuracy: 72.27%
# Epoch 108
# 	train - loss: 7.78e-01
# 	val - loss: -0.5340435057878494, accuracy: 72.27%
# Epoch 109
# 	train - loss: 7.73e-01
# 	val - loss: -0.5361979156732559, accuracy: 72.27%
# Epoch 110
# 	train - loss: 7.69e-01
# 	val - loss: -0.5383065640926361, accuracy: 72.66%
# Epoch 111
# 	train - loss: 7.64e-01
# 	val - loss: -0.5404092073440552, accuracy: 73.05%
# Epoch 112
# 	train - loss: 7.60e-01
# 	val - loss: -0.5424886494874954, accuracy: 73.05%
# Epoch 113
# 	train - loss: 7.55e-01
# 	val - loss: -0.5445344150066376, accuracy: 73.05%
# Epoch 114
# 	train - loss: 7.51e-01
# 	val - loss: -0.5465584546327591, accuracy: 73.44%
# Epoch 115
# 	train - loss: 7.47e-01
# 	val - loss: -0.5485955625772476, accuracy: 73.44%
# Epoch 116
# 	train - loss: 7.43e-01
# 	val - loss: -0.5505845099687576, accuracy: 73.83%
# Epoch 117
# 	train - loss: 7.38e-01
# 	val - loss: -0.5525689721107483, accuracy: 73.83%
# Epoch 118
# 	train - loss: 7.34e-01
# 	val - loss: -0.5545269548892975, accuracy: 74.22%
# Epoch 119
# 	train - loss: 7.30e-01
# 	val - loss: -0.556482657790184, accuracy: 74.61%
# Epoch 120
# 	train - loss: 7.26e-01
# 	val - loss: -0.5584320276975632, accuracy: 75.00%
# Epoch 121
# 	train - loss: 7.22e-01
# 	val - loss: -0.5603451579809189, accuracy: 75.39%
# Epoch 122
# 	train - loss: 7.18e-01
# 	val - loss: -0.5622495263814926, accuracy: 75.39%
# Epoch 123
# 	train - loss: 7.14e-01
# 	val - loss: -0.564161479473114, accuracy: 75.78%
# Epoch 124
# 	train - loss: 7.10e-01
# 	val - loss: -0.5660487711429596, accuracy: 75.78%
# Epoch 125
# 	train - loss: 7.06e-01
# 	val - loss: -0.5679244697093964, accuracy: 75.78%
# Epoch 126
# 	train - loss: 7.02e-01
# 	val - loss: -0.5697803050279617, accuracy: 75.78%
# Epoch 127
# 	train - loss: 6.98e-01
# 	val - loss: -0.5716379880905151, accuracy: 75.78%
# Epoch 128
# 	train - loss: 6.94e-01
# 	val - loss: -0.573477178812027, accuracy: 75.78%
# Epoch 129
# 	train - loss: 6.90e-01
# 	val - loss: -0.5753158181905746, accuracy: 75.78%
# Epoch 130
# 	train - loss: 6.86e-01
# 	val - loss: -0.5771371722221375, accuracy: 76.56%
# Epoch 131
# 	train - loss: 6.82e-01
# 	val - loss: -0.5789277404546738, accuracy: 76.56%
# Epoch 132
# 	train - loss: 6.79e-01
# 	val - loss: -0.5807003229856491, accuracy: 76.56%
# Epoch 133
# 	train - loss: 6.75e-01
# 	val - loss: -0.5824912786483765, accuracy: 76.95%
# Epoch 134
# 	train - loss: 6.71e-01
# 	val - loss: -0.584253653883934, accuracy: 76.95%
# Epoch 135
# 	train - loss: 6.67e-01
# 	val - loss: -0.5860167592763901, accuracy: 76.95%
# Epoch 136
# 	train - loss: 6.64e-01
# 	val - loss: -0.5877417325973511, accuracy: 77.34%
# Epoch 137
# 	train - loss: 6.60e-01
# 	val - loss: -0.5894904136657715, accuracy: 77.34%
# Epoch 138
# 	train - loss: 6.56e-01
# 	val - loss: -0.5912032425403595, accuracy: 77.34%
# Epoch 139
# 	train - loss: 6.53e-01
# 	val - loss: -0.5929287821054459, accuracy: 77.34%
# Epoch 140
# 	train - loss: 6.49e-01
# 	val - loss: -0.5946159511804581, accuracy: 77.34%
# Epoch 141
# 	train - loss: 6.46e-01
# 	val - loss: -0.5963170975446701, accuracy: 77.34%
# Epoch 142
# 	train - loss: 6.42e-01
# 	val - loss: -0.5979935526847839, accuracy: 77.73%
# Epoch 143
# 	train - loss: 6.38e-01
# 	val - loss: -0.5996904373168945, accuracy: 77.73%
# Epoch 144
# 	train - loss: 6.35e-01
# 	val - loss: -0.601343184709549, accuracy: 77.73%
# Epoch 145
# 	train - loss: 6.31e-01
# 	val - loss: -0.6029888242483139, accuracy: 77.73%
# Epoch 146
# 	train - loss: 6.28e-01
# 	val - loss: -0.6046375036239624, accuracy: 77.73%
# Epoch 147
# 	train - loss: 6.25e-01
# 	val - loss: -0.6062921434640884, accuracy: 78.12%
# Epoch 148
# 	train - loss: 6.21e-01
# 	val - loss: -0.6079125106334686, accuracy: 78.12%
# Epoch 149
# 	train - loss: 6.18e-01
# 	val - loss: -0.6095510572195053, accuracy: 78.52%
# Epoch 150
# 	train - loss: 6.14e-01
# 	val - loss: -0.611160397529602, accuracy: 78.52%
# Epoch 151
# 	train - loss: 6.11e-01
# 	val - loss: -0.6127699464559555, accuracy: 78.52%
# Epoch 152
# 	train - loss: 6.08e-01
# 	val - loss: -0.6143748760223389, accuracy: 78.52%
# Epoch 153
# 	train - loss: 6.04e-01
# 	val - loss: -0.6159633249044418, accuracy: 78.52%
# Epoch 154
# 	train - loss: 6.01e-01
# 	val - loss: -0.6175650209188461, accuracy: 78.52%
# Epoch 155
# 	train - loss: 5.98e-01
# 	val - loss: -0.6191553026437759, accuracy: 78.52%
# Epoch 156
# 	train - loss: 5.94e-01
# 	val - loss: -0.6207073777914047, accuracy: 78.52%
# Epoch 157
# 	train - loss: 5.91e-01
# 	val - loss: -0.6222887188196182, accuracy: 78.52%
# Epoch 158
# 	train - loss: 5.88e-01
# 	val - loss: -0.6238496899604797, accuracy: 78.52%
# Epoch 159
# 	train - loss: 5.85e-01
# 	val - loss: -0.6253856271505356, accuracy: 78.52%
# Epoch 160
# 	train - loss: 5.82e-01
# 	val - loss: -0.6269296258687973, accuracy: 78.52%
# Epoch 161
# 	train - loss: 5.78e-01
# 	val - loss: -0.6284979730844498, accuracy: 78.91%
# Epoch 162
# 	train - loss: 5.75e-01
# 	val - loss: -0.6300264894962311, accuracy: 78.91%
# Epoch 163
# 	train - loss: 5.72e-01
# 	val - loss: -0.6315613985061646, accuracy: 79.30%
# Epoch 164
# 	train - loss: 5.69e-01
# 	val - loss: -0.6330879926681519, accuracy: 79.30%
# Epoch 165
# 	train - loss: 5.66e-01
# 	val - loss: -0.6346019059419632, accuracy: 79.30%
# Epoch 166
# 	train - loss: 5.63e-01
# 	val - loss: -0.636103019118309, accuracy: 79.30%
# Epoch 167
# 	train - loss: 5.60e-01
# 	val - loss: -0.6376015841960907, accuracy: 79.69%
# Epoch 168
# 	train - loss: 5.57e-01
# 	val - loss: -0.6391031593084335, accuracy: 79.69%
# Epoch 169
# 	train - loss: 5.54e-01
# 	val - loss: -0.6405818164348602, accuracy: 79.69%
# Epoch 170
# 	train - loss: 5.51e-01
# 	val - loss: -0.6420551836490631, accuracy: 79.69%
# Epoch 171
# 	train - loss: 5.48e-01
# 	val - loss: -0.6435332745313644, accuracy: 79.69%
# Epoch 172
# 	train - loss: 5.45e-01
# 	val - loss: -0.6449852734804153, accuracy: 79.69%
# Epoch 173
# 	train - loss: 5.42e-01
# 	val - loss: -0.6464245021343231, accuracy: 80.08%
# Epoch 174
# 	train - loss: 5.39e-01
# 	val - loss: -0.6478878259658813, accuracy: 80.47%
# Epoch 175
# 	train - loss: 5.36e-01
# 	val - loss: -0.6493345946073532, accuracy: 80.47%
# Epoch 176
# 	train - loss: 5.33e-01
# 	val - loss: -0.650751456618309, accuracy: 80.47%
# Epoch 177
# 	train - loss: 5.30e-01
# 	val - loss: -0.6521972715854645, accuracy: 80.47%
# Epoch 178
# 	train - loss: 5.27e-01
# 	val - loss: -0.6536136269569397, accuracy: 80.47%
# Epoch 179
# 	train - loss: 5.24e-01
# 	val - loss: -0.6550220847129822, accuracy: 80.86%
# Epoch 180
# 	train - loss: 5.22e-01
# 	val - loss: -0.6564491093158722, accuracy: 80.86%
# Epoch 181
# 	train - loss: 5.19e-01
# 	val - loss: -0.6578307598829269, accuracy: 80.86%
# Epoch 182
# 	train - loss: 5.16e-01
# 	val - loss: -0.6592117846012115, accuracy: 80.86%
# Epoch 183
# 	train - loss: 5.13e-01
# 	val - loss: -0.6606073081493378, accuracy: 80.86%
# Epoch 184
# 	train - loss: 5.10e-01
# 	val - loss: -0.6619790345430374, accuracy: 80.86%
# Epoch 185
# 	train - loss: 5.08e-01
# 	val - loss: -0.6633568704128265, accuracy: 81.25%
# Epoch 186
# 	train - loss: 5.05e-01
# 	val - loss: -0.6647268533706665, accuracy: 81.25%
# Epoch 187
# 	train - loss: 5.02e-01
# 	val - loss: -0.6660939455032349, accuracy: 81.25%
# Epoch 188
# 	train - loss: 5.00e-01
# 	val - loss: -0.6674602329730988, accuracy: 81.25%
# Epoch 189
# 	train - loss: 4.97e-01
# 	val - loss: -0.6687779277563095, accuracy: 81.25%
# Epoch 190
# 	train - loss: 4.94e-01
# 	val - loss: -0.6701378226280212, accuracy: 81.25%
# Epoch 191
# 	train - loss: 4.92e-01
# 	val - loss: -0.6714673638343811, accuracy: 81.25%
# Epoch 192
# 	train - loss: 4.89e-01
# 	val - loss: -0.6727751195430756, accuracy: 81.25%
# Epoch 193
# 	train - loss: 4.86e-01
# 	val - loss: -0.6740996092557907, accuracy: 81.64%
# Epoch 194
# 	train - loss: 4.84e-01
# 	val - loss: -0.6754234731197357, accuracy: 81.64%
# Epoch 195
# 	train - loss: 4.81e-01
# 	val - loss: -0.6767326891422272, accuracy: 81.64%
# Epoch 196
# 	train - loss: 4.79e-01
# 	val - loss: -0.6780192106962204, accuracy: 82.03%
# Epoch 197
# 	train - loss: 4.76e-01
# 	val - loss: -0.6793034672737122, accuracy: 82.03%
# Epoch 198
# 	train - loss: 4.74e-01
# 	val - loss: -0.6805973798036575, accuracy: 82.03%
# Epoch 199
# 	train - loss: 4.71e-01
# 	val - loss: -0.6818888932466507, accuracy: 82.03%
# Epoch 200
# 	train - loss: 4.69e-01
# 	val - loss: -0.6831587851047516, accuracy: 82.03%
# Epoch 201
# 	train - loss: 4.66e-01
# 	val - loss: -0.6844266355037689, accuracy: 82.03%
# Epoch 202
# 	train - loss: 4.64e-01
# 	val - loss: -0.6857071220874786, accuracy: 82.03%
# Epoch 203
# 	train - loss: 4.62e-01
# 	val - loss: -0.6869465857744217, accuracy: 82.03%
# Epoch 204
# 	train - loss: 4.59e-01
# 	val - loss: -0.6881826519966125, accuracy: 82.03%
# Epoch 205
# 	train - loss: 4.57e-01
# 	val - loss: -0.6894299536943436, accuracy: 82.03%
# Epoch 206
# 	train - loss: 4.54e-01
# 	val - loss: -0.6906764954328537, accuracy: 82.03%
# Epoch 207
# 	train - loss: 4.52e-01
# 	val - loss: -0.6919137984514236, accuracy: 82.03%
# Epoch 208
# 	train - loss: 4.50e-01
# 	val - loss: -0.6931214481592178, accuracy: 82.03%
# Epoch 209
# 	train - loss: 4.47e-01
# 	val - loss: -0.6943297535181046, accuracy: 82.03%
# Epoch 210
# 	train - loss: 4.45e-01
# 	val - loss: -0.695567786693573, accuracy: 82.42%
# Epoch 211
# 	train - loss: 4.43e-01
# 	val - loss: -0.696753591299057, accuracy: 82.42%
# Epoch 212
# 	train - loss: 4.41e-01
# 	val - loss: -0.6979607194662094, accuracy: 82.81%
# Epoch 213
# 	train - loss: 4.38e-01
# 	val - loss: -0.6991466581821442, accuracy: 82.81%
# Epoch 214
# 	train - loss: 4.36e-01
# 	val - loss: -0.7003195881843567, accuracy: 82.81%
# Epoch 215
# 	train - loss: 4.34e-01
# 	val - loss: -0.7014980465173721, accuracy: 82.81%
# Epoch 216
# 	train - loss: 4.32e-01
# 	val - loss: -0.7026591300964355, accuracy: 82.81%
# Epoch 217
# 	train - loss: 4.30e-01
# 	val - loss: -0.7038115710020065, accuracy: 82.81%
# Epoch 218
# 	train - loss: 4.27e-01
# 	val - loss: -0.7049542814493179, accuracy: 82.81%
# Epoch 219
# 	train - loss: 4.25e-01
# 	val - loss: -0.7060993164777756, accuracy: 82.81%
# Epoch 220
# 	train - loss: 4.23e-01
# 	val - loss: -0.7072229087352753, accuracy: 82.81%
# Epoch 221
# 	train - loss: 4.21e-01
# 	val - loss: -0.7083651572465897, accuracy: 82.81%
# Epoch 222
# 	train - loss: 4.19e-01
# 	val - loss: -0.7094723433256149, accuracy: 82.81%
# Epoch 223
# 	train - loss: 4.17e-01
# 	val - loss: -0.710593655705452, accuracy: 82.81%
# Epoch 224
# 	train - loss: 4.15e-01
# 	val - loss: -0.7116971611976624, accuracy: 82.81%
# Epoch 225
# 	train - loss: 4.13e-01
# 	val - loss: -0.7128087878227234, accuracy: 82.81%
# Epoch 226
# 	train - loss: 4.11e-01
# 	val - loss: -0.7139264792203903, accuracy: 82.81%
# Epoch 227
# 	train - loss: 4.09e-01
# 	val - loss: -0.7149911671876907, accuracy: 82.81%
# Epoch 228
# 	train - loss: 4.07e-01
# 	val - loss: -0.7161016315221786, accuracy: 82.81%
# Epoch 229
# 	train - loss: 4.05e-01
# 	val - loss: -0.7171655297279358, accuracy: 82.81%
# Epoch 230
# 	train - loss: 4.03e-01
# 	val - loss: -0.7182291895151138, accuracy: 82.81%
# Epoch 231
# 	train - loss: 4.01e-01
# 	val - loss: -0.7192909121513367, accuracy: 82.81%
# Epoch 232
# 	train - loss: 3.99e-01
# 	val - loss: -0.7203634977340698, accuracy: 82.81%
# Epoch 233
# 	train - loss: 3.97e-01
# 	val - loss: -0.7213973104953766, accuracy: 82.81%
# Epoch 234
# 	train - loss: 3.95e-01
# 	val - loss: -0.7224568724632263, accuracy: 82.81%
# Epoch 235
# 	train - loss: 3.93e-01
# 	val - loss: -0.7234960198402405, accuracy: 82.81%
# Epoch 236
# 	train - loss: 3.91e-01
# 	val - loss: -0.7245099395513535, accuracy: 82.81%
# Epoch 237
# 	train - loss: 3.89e-01
# 	val - loss: -0.7255382090806961, accuracy: 82.81%
# Epoch 238
# 	train - loss: 3.87e-01
# 	val - loss: -0.7265425771474838, accuracy: 82.81%
# Epoch 239
# 	train - loss: 3.85e-01
# 	val - loss: -0.7275522351264954, accuracy: 83.20%
# Epoch 240
# 	train - loss: 3.83e-01
# 	val - loss: -0.7285474240779877, accuracy: 83.20%
# Epoch 241
# 	train - loss: 3.82e-01
# 	val - loss: -0.7295417189598083, accuracy: 83.20%
# Epoch 242
# 	train - loss: 3.80e-01
# 	val - loss: -0.730533242225647, accuracy: 83.20%
# Epoch 243
# 	train - loss: 3.78e-01
# 	val - loss: -0.7315172851085663, accuracy: 83.20%
# Epoch 244
# 	train - loss: 3.76e-01
# 	val - loss: -0.7324824184179306, accuracy: 83.20%
# Epoch 245
# 	train - loss: 3.74e-01
# 	val - loss: -0.7334558814764023, accuracy: 83.20%
# Epoch 246
# 	train - loss: 3.73e-01
# 	val - loss: -0.7344105094671249, accuracy: 83.20%
# Epoch 247
# 	train - loss: 3.71e-01
# 	val - loss: -0.7353768050670624, accuracy: 83.20%
# Epoch 248
# 	train - loss: 3.69e-01
# 	val - loss: -0.7363330721855164, accuracy: 83.20%
# Epoch 249
# 	train - loss: 3.68e-01
# 	val - loss: -0.737265095114708, accuracy: 83.20%
# Epoch 250
# 	train - loss: 3.66e-01
# 	val - loss: -0.7382119297981262, accuracy: 83.20%
# Epoch 251
# 	train - loss: 3.64e-01
# 	val - loss: -0.7391385585069656, accuracy: 83.59%
# Epoch 252
# 	train - loss: 3.62e-01
# 	val - loss: -0.7400486767292023, accuracy: 83.59%
# Epoch 253
# 	train - loss: 3.61e-01
# 	val - loss: -0.7409985512495041, accuracy: 83.59%
# Epoch 254
# 	train - loss: 3.59e-01
# 	val - loss: -0.7418969720602036, accuracy: 83.98%
# Epoch 255
# 	train - loss: 3.58e-01
# 	val - loss: -0.7428177297115326, accuracy: 83.98%
# Epoch 256
# 	train - loss: 3.56e-01
# 	val - loss: -0.7437129765748978, accuracy: 84.38%
# Epoch 257
# 	train - loss: 3.54e-01
# 	val - loss: -0.744612067937851, accuracy: 84.77%
# Epoch 258
# 	train - loss: 3.53e-01
# 	val - loss: -0.7455055862665176, accuracy: 84.77%
# Epoch 259
# 	train - loss: 3.51e-01
# 	val - loss: -0.7463911920785904, accuracy: 84.77%
# Epoch 260
# 	train - loss: 3.50e-01
# 	val - loss: -0.7472764998674393, accuracy: 84.77%
# Epoch 261
# 	train - loss: 3.48e-01
# 	val - loss: -0.7481316179037094, accuracy: 84.77%
# Epoch 262
# 	train - loss: 3.46e-01
# 	val - loss: -0.7489974796772003, accuracy: 84.77%
# Epoch 263
# 	train - loss: 3.45e-01
# 	val - loss: -0.749854788184166, accuracy: 85.16%
# Epoch 264
# 	train - loss: 3.43e-01
# 	val - loss: -0.7507083415985107, accuracy: 85.16%
# Epoch 265
# 	train - loss: 3.42e-01
# 	val - loss: -0.751547321677208, accuracy: 85.16%
# Epoch 266
# 	train - loss: 3.40e-01
# 	val - loss: -0.7523893564939499, accuracy: 85.55%
# Epoch 267
# 	train - loss: 3.39e-01
# 	val - loss: -0.7532227635383606, accuracy: 85.55%
# Epoch 268
# 	train - loss: 3.37e-01
# 	val - loss: -0.7540516406297684, accuracy: 85.55%
# Epoch 269
# 	train - loss: 3.36e-01
# 	val - loss: -0.7548536211252213, accuracy: 85.55%
# Epoch 270
# 	train - loss: 3.34e-01
# 	val - loss: -0.7556706368923187, accuracy: 85.55%
# Epoch 271
# 	train - loss: 3.33e-01
# 	val - loss: -0.7564978897571564, accuracy: 85.55%
# Epoch 272
# 	train - loss: 3.32e-01
# 	val - loss: -0.7572872638702393, accuracy: 85.55%
# Epoch 273
# 	train - loss: 3.30e-01
# 	val - loss: -0.7580857276916504, accuracy: 85.55%
# Epoch 274
# 	train - loss: 3.29e-01
# 	val - loss: -0.7588624060153961, accuracy: 85.55%
# Epoch 275
# 	train - loss: 3.27e-01
# 	val - loss: -0.7596515417098999, accuracy: 85.55%
# Epoch 276
# 	train - loss: 3.26e-01
# 	val - loss: -0.7604380249977112, accuracy: 85.55%
# Epoch 277
# 	train - loss: 3.25e-01
# 	val - loss: -0.7612213492393494, accuracy: 85.94%
# Epoch 278
# 	train - loss: 3.23e-01
# 	val - loss: -0.7619855999946594, accuracy: 86.33%
# Epoch 279
# 	train - loss: 3.22e-01
# 	val - loss: -0.7627779096364975, accuracy: 86.33%
# Epoch 280
# 	train - loss: 3.20e-01
# 	val - loss: -0.7635251432657242, accuracy: 86.33%
# Epoch 281
# 	train - loss: 3.19e-01
# 	val - loss: -0.7642772942781448, accuracy: 86.33%
# Epoch 282
# 	train - loss: 3.18e-01
# 	val - loss: -0.7650338113307953, accuracy: 86.33%
# Epoch 283
# 	train - loss: 3.16e-01
# 	val - loss: -0.7657852172851562, accuracy: 86.33%
# Epoch 284
# 	train - loss: 3.15e-01
# 	val - loss: -0.7665258049964905, accuracy: 86.33%
# Epoch 285
# 	train - loss: 3.14e-01
# 	val - loss: -0.7672578245401382, accuracy: 86.33%
# Epoch 286
# 	train - loss: 3.12e-01
# 	val - loss: -0.7679909318685532, accuracy: 86.33%
# Epoch 287
# 	train - loss: 3.11e-01
# 	val - loss: -0.7687129974365234, accuracy: 86.33%
# Epoch 288
# 	train - loss: 3.10e-01
# 	val - loss: -0.7694336175918579, accuracy: 86.33%
# Epoch 289
# 	train - loss: 3.09e-01
# 	val - loss: -0.7701363563537598, accuracy: 86.33%
# Epoch 290
# 	train - loss: 3.07e-01
# 	val - loss: -0.7708875238895416, accuracy: 86.33%
# Epoch 291
# 	train - loss: 3.06e-01
# 	val - loss: -0.7715777009725571, accuracy: 86.33%
# Epoch 292
# 	train - loss: 3.05e-01
# 	val - loss: -0.7722751945257187, accuracy: 86.33%
# Epoch 293
# 	train - loss: 3.04e-01
# 	val - loss: -0.772978737950325, accuracy: 86.33%
# Epoch 294
# 	train - loss: 3.02e-01
# 	val - loss: -0.7736656367778778, accuracy: 86.33%
# Epoch 295
# 	train - loss: 3.01e-01
# 	val - loss: -0.7743655294179916, accuracy: 86.33%
# Epoch 296
# 	train - loss: 3.00e-01
# 	val - loss: -0.775044247508049, accuracy: 86.33%
# Epoch 297
# 	train - loss: 2.99e-01
# 	val - loss: -0.7757360488176346, accuracy: 86.33%
# Epoch 298
# 	train - loss: 2.98e-01
# 	val - loss: -0.7764077037572861, accuracy: 86.33%
# Epoch 299
# 	train - loss: 2.96e-01
# 	val - loss: -0.7770768851041794, accuracy: 86.72%
# Epoch 300
# 	train - loss: 2.95e-01
# 	val - loss: -0.7777617573738098, accuracy: 86.72%
# Epoch 301
# 	train - loss: 2.94e-01
# 	val - loss: -0.7784251272678375, accuracy: 86.72%
# Epoch 302
# 	train - loss: 2.93e-01
# 	val - loss: -0.7790942788124084, accuracy: 87.11%
# Epoch 303
# 	train - loss: 2.92e-01
# 	val - loss: -0.7797285616397858, accuracy: 87.11%
# Epoch 304
# 	train - loss: 2.91e-01
# 	val - loss: -0.7803808003664017, accuracy: 87.11%
# Epoch 305
# 	train - loss: 2.89e-01
# 	val - loss: -0.7810317277908325, accuracy: 87.11%
# Epoch 306
# 	train - loss: 2.88e-01
# 	val - loss: -0.7816728204488754, accuracy: 87.11%
# Epoch 307
# 	train - loss: 2.87e-01
# 	val - loss: -0.7823003828525543, accuracy: 87.11%
# Epoch 308
# 	train - loss: 2.86e-01
# 	val - loss: -0.7829601615667343, accuracy: 87.11%
# Epoch 309
# 	train - loss: 2.85e-01
# 	val - loss: -0.7835854589939117, accuracy: 87.11%
# Epoch 310
# 	train - loss: 2.84e-01
# 	val - loss: -0.784188911318779, accuracy: 87.11%
# Epoch 311
# 	train - loss: 2.83e-01
# 	val - loss: -0.7848347872495651, accuracy: 87.11%
# Epoch 312
# 	train - loss: 2.82e-01
# 	val - loss: -0.785450279712677, accuracy: 87.11%
# Epoch 313
# 	train - loss: 2.81e-01
# 	val - loss: -0.7860558331012726, accuracy: 87.50%
# Epoch 314
# 	train - loss: 2.79e-01
# 	val - loss: -0.7866801768541336, accuracy: 87.89%
# Epoch 315
# 	train - loss: 2.78e-01
# 	val - loss: -0.7872959673404694, accuracy: 88.28%
# Epoch 316
# 	train - loss: 2.77e-01
# 	val - loss: -0.7878853380680084, accuracy: 88.28%
# Epoch 317
# 	train - loss: 2.76e-01
# 	val - loss: -0.7884858846664429, accuracy: 88.28%
# Epoch 318
# 	train - loss: 2.75e-01
# 	val - loss: -0.7890837341547012, accuracy: 88.28%
# Epoch 319
# 	train - loss: 2.74e-01
# 	val - loss: -0.7896746397018433, accuracy: 88.28%
# Epoch 320
# 	train - loss: 2.73e-01
# 	val - loss: -0.7902563512325287, accuracy: 88.28%
# Epoch 321
# 	train - loss: 2.72e-01
# 	val - loss: -0.7908485978841782, accuracy: 88.28%
# Epoch 322
# 	train - loss: 2.71e-01
# 	val - loss: -0.7914204299449921, accuracy: 88.28%
# Epoch 323
# 	train - loss: 2.70e-01
# 	val - loss: -0.7919950485229492, accuracy: 88.28%
# Epoch 324
# 	train - loss: 2.69e-01
# 	val - loss: -0.7925696521997452, accuracy: 88.28%
# Epoch 325
# 	train - loss: 2.68e-01
# 	val - loss: -0.7931342273950577, accuracy: 88.28%
# Epoch 326
# 	train - loss: 2.67e-01
# 	val - loss: -0.7936989516019821, accuracy: 88.28%
# Epoch 327
# 	train - loss: 2.66e-01
# 	val - loss: -0.7942630648612976, accuracy: 88.28%
# Epoch 328
# 	train - loss: 2.65e-01
# 	val - loss: -0.794819101691246, accuracy: 88.28%
# Epoch 329
# 	train - loss: 2.64e-01
# 	val - loss: -0.7953628599643707, accuracy: 88.28%
# Epoch 330
# 	train - loss: 2.63e-01
# 	val - loss: -0.7959205210208893, accuracy: 88.28%
# Epoch 331
# 	train - loss: 2.62e-01
# 	val - loss: -0.796454980969429, accuracy: 88.28%
# Epoch 332
# 	train - loss: 2.61e-01
# 	val - loss: -0.7970089763402939, accuracy: 88.28%
# Epoch 333
# 	train - loss: 2.60e-01
# 	val - loss: -0.7975353300571442, accuracy: 88.28%
# Epoch 334
# 	train - loss: 2.59e-01
# 	val - loss: -0.798086017370224, accuracy: 88.28%
# Epoch 335
# 	train - loss: 2.58e-01
# 	val - loss: -0.7986041605472565, accuracy: 88.28%
# Epoch 336
# 	train - loss: 2.57e-01
# 	val - loss: -0.7991378605365753, accuracy: 88.28%
# Epoch 337
# 	train - loss: 2.56e-01
# 	val - loss: -0.7996620386838913, accuracy: 88.28%
# Epoch 338
# 	train - loss: 2.56e-01
# 	val - loss: -0.8001921623945236, accuracy: 88.67%
# Epoch 339
# 	train - loss: 2.55e-01
# 	val - loss: -0.8007066398859024, accuracy: 88.67%
# Epoch 340
# 	train - loss: 2.54e-01
# 	val - loss: -0.8012291342020035, accuracy: 88.67%
# Epoch 341
# 	train - loss: 2.53e-01
# 	val - loss: -0.8017543256282806, accuracy: 88.67%
# Epoch 342
# 	train - loss: 2.52e-01
# 	val - loss: -0.8022566437721252, accuracy: 88.67%
# Epoch 343
# 	train - loss: 2.51e-01
# 	val - loss: -0.8027625977993011, accuracy: 88.67%
# Epoch 344
# 	train - loss: 2.50e-01
# 	val - loss: -0.8032730668783188, accuracy: 88.67%
# Epoch 345
# 	train - loss: 2.49e-01
# 	val - loss: -0.803778350353241, accuracy: 88.67%
# Epoch 346
# 	train - loss: 2.48e-01
# 	val - loss: -0.8042823523283005, accuracy: 88.67%
# Epoch 347
# 	train - loss: 2.47e-01
# 	val - loss: -0.804792121052742, accuracy: 88.67%
# Epoch 348
# 	train - loss: 2.47e-01
# 	val - loss: -0.8052741885185242, accuracy: 88.67%
# Epoch 349
# 	train - loss: 2.46e-01
# 	val - loss: -0.8057619482278824, accuracy: 88.67%
# Epoch 350
# 	train - loss: 2.45e-01
# 	val - loss: -0.8062520623207092, accuracy: 88.67%
# Epoch 351
# 	train - loss: 2.44e-01
# 	val - loss: -0.806722104549408, accuracy: 88.67%
# Epoch 352
# 	train - loss: 2.43e-01
# 	val - loss: -0.8072183579206467, accuracy: 88.67%
# Epoch 353
# 	train - loss: 2.42e-01
# 	val - loss: -0.8076979964971542, accuracy: 88.67%
# Epoch 354
# 	train - loss: 2.41e-01
# 	val - loss: -0.8081769943237305, accuracy: 88.67%
# Epoch 355
# 	train - loss: 2.41e-01
# 	val - loss: -0.8086482286453247, accuracy: 89.06%
# Epoch 356
# 	train - loss: 2.40e-01
# 	val - loss: -0.8091213703155518, accuracy: 89.06%
# Epoch 357
# 	train - loss: 2.39e-01
# 	val - loss: -0.8095787465572357, accuracy: 89.06%
# Epoch 358
# 	train - loss: 2.38e-01
# 	val - loss: -0.8100639581680298, accuracy: 89.06%
# Epoch 359
# 	train - loss: 2.37e-01
# 	val - loss: -0.8105171173810959, accuracy: 89.06%
# Epoch 360
# 	train - loss: 2.36e-01
# 	val - loss: -0.8109802603721619, accuracy: 89.06%
# Epoch 361
# 	train - loss: 2.36e-01
# 	val - loss: -0.8114416897296906, accuracy: 89.06%
# Epoch 362
# 	train - loss: 2.35e-01
# 	val - loss: -0.8118957579135895, accuracy: 89.06%
# Epoch 363
# 	train - loss: 2.34e-01
# 	val - loss: -0.8123587071895599, accuracy: 89.06%
# Epoch 364
# 	train - loss: 2.33e-01
# 	val - loss: -0.8128129243850708, accuracy: 89.06%
# Epoch 365
# 	train - loss: 2.32e-01
# 	val - loss: -0.8132570832967758, accuracy: 89.06%
# Epoch 366
# 	train - loss: 2.31e-01
# 	val - loss: -0.8137029260396957, accuracy: 89.06%
# Epoch 367
# 	train - loss: 2.31e-01
# 	val - loss: -0.8141400068998337, accuracy: 89.06%
# Epoch 368
# 	train - loss: 2.30e-01
# 	val - loss: -0.8145851343870163, accuracy: 89.06%
# Epoch 369
# 	train - loss: 2.29e-01
# 	val - loss: -0.8150392919778824, accuracy: 89.06%
# Epoch 370
# 	train - loss: 2.28e-01
# 	val - loss: -0.8154619783163071, accuracy: 89.06%
# Epoch 371
# 	train - loss: 2.28e-01
# 	val - loss: -0.8159087300300598, accuracy: 89.06%
# Epoch 372
# 	train - loss: 2.27e-01
# 	val - loss: -0.8163307160139084, accuracy: 89.06%
# Epoch 373
# 	train - loss: 2.26e-01
# 	val - loss: -0.8167761862277985, accuracy: 89.06%
# Epoch 374
# 	train - loss: 2.25e-01
# 	val - loss: -0.8171919882297516, accuracy: 89.06%
# Epoch 375
# 	train - loss: 2.25e-01
# 	val - loss: -0.81761734187603, accuracy: 89.06%
# Epoch 376
# 	train - loss: 2.24e-01
# 	val - loss: -0.8180366605520248, accuracy: 89.06%
# Epoch 377
# 	train - loss: 2.23e-01
# 	val - loss: -0.8184654414653778, accuracy: 89.06%
# Epoch 378
# 	train - loss: 2.22e-01
# 	val - loss: -0.8188768625259399, accuracy: 89.06%
# Epoch 379
# 	train - loss: 2.22e-01
# 	val - loss: -0.819299191236496, accuracy: 89.06%
# Epoch 380
# 	train - loss: 2.21e-01
# 	val - loss: -0.819711297750473, accuracy: 89.45%
# Epoch 381
# 	train - loss: 2.20e-01
# 	val - loss: -0.820120632648468, accuracy: 89.45%
# Epoch 382
# 	train - loss: 2.19e-01
# 	val - loss: -0.8205343037843704, accuracy: 89.45%
# Epoch 383
# 	train - loss: 2.19e-01
# 	val - loss: -0.8209492713212967, accuracy: 89.45%
# Epoch 384
# 	train - loss: 2.18e-01
# 	val - loss: -0.821349561214447, accuracy: 89.45%
# Epoch 385
# 	train - loss: 2.17e-01
# 	val - loss: -0.8217440545558929, accuracy: 89.45%
# Epoch 386
# 	train - loss: 2.16e-01
# 	val - loss: -0.8221457451581955, accuracy: 89.45%
# Epoch 387
# 	train - loss: 2.16e-01
# 	val - loss: -0.8225536197423935, accuracy: 89.45%
# Epoch 388
# 	train - loss: 2.15e-01
# 	val - loss: -0.8229263871908188, accuracy: 89.45%
# Epoch 389
# 	train - loss: 2.14e-01
# 	val - loss: -0.8233333379030228, accuracy: 89.45%
# Epoch 390
# 	train - loss: 2.14e-01
# 	val - loss: -0.8237274736166, accuracy: 89.45%
# Epoch 391
# 	train - loss: 2.13e-01
# 	val - loss: -0.8241186887025833, accuracy: 89.45%
# Epoch 392
# 	train - loss: 2.12e-01
# 	val - loss: -0.8244930505752563, accuracy: 89.45%
# Epoch 393
# 	train - loss: 2.12e-01
# 	val - loss: -0.8248668611049652, accuracy: 89.45%
# Epoch 394
# 	train - loss: 2.11e-01
# 	val - loss: -0.825260117650032, accuracy: 89.45%
# Epoch 395
# 	train - loss: 2.10e-01
# 	val - loss: -0.8256485015153885, accuracy: 89.45%
# Epoch 396
# 	train - loss: 2.10e-01
# 	val - loss: -0.8260182440280914, accuracy: 89.45%
# Epoch 397
# 	train - loss: 2.09e-01
# 	val - loss: -0.8263993859291077, accuracy: 89.45%
# Epoch 398
# 	train - loss: 2.08e-01
# 	val - loss: -0.8267729878425598, accuracy: 89.45%
# Epoch 399
# 	train - loss: 2.08e-01
# 	val - loss: -0.8271639943122864, accuracy: 89.45%
# Epoch 400
# 	train - loss: 2.07e-01
# 	val - loss: -0.8275188207626343, accuracy: 89.45%
# Epoch 401
# 	train - loss: 2.06e-01
# 	val - loss: -0.8279092162847519, accuracy: 89.45%
# Epoch 402
# 	train - loss: 2.06e-01
# 	val - loss: -0.8282674551010132, accuracy: 89.45%
# Epoch 403
# 	train - loss: 2.05e-01
# 	val - loss: -0.8286471962928772, accuracy: 89.45%
# Epoch 404
# 	train - loss: 2.04e-01
# 	val - loss: -0.8289904147386551, accuracy: 89.45%
# Epoch 405
# 	train - loss: 2.04e-01
# 	val - loss: -0.8293511420488358, accuracy: 89.45%
# Epoch 406
# 	train - loss: 2.03e-01
# 	val - loss: -0.8297124803066254, accuracy: 89.45%
# Epoch 407
# 	train - loss: 2.02e-01
# 	val - loss: -0.8300586640834808, accuracy: 89.45%
# Epoch 408
# 	train - loss: 2.02e-01
# 	val - loss: -0.8304335623979568, accuracy: 89.45%
# Epoch 409
# 	train - loss: 2.01e-01
# 	val - loss: -0.8307868242263794, accuracy: 89.45%
# Epoch 410
# 	train - loss: 2.01e-01
# 	val - loss: -0.8311473280191422, accuracy: 89.45%
# Epoch 411
# 	train - loss: 2.00e-01
# 	val - loss: -0.8314782530069351, accuracy: 89.84%
# Epoch 412
# 	train - loss: 1.99e-01
# 	val - loss: -0.831839308142662, accuracy: 89.84%
# Epoch 413
# 	train - loss: 1.99e-01
# 	val - loss: -0.8321798145771027, accuracy: 89.84%
# Epoch 414
# 	train - loss: 1.98e-01
# 	val - loss: -0.8325223475694656, accuracy: 89.84%
# Epoch 415
# 	train - loss: 1.97e-01
# 	val - loss: -0.8328656256198883, accuracy: 89.84%
# Epoch 416
# 	train - loss: 1.97e-01
# 	val - loss: -0.8332126438617706, accuracy: 89.84%
# Epoch 417
# 	train - loss: 1.96e-01
# 	val - loss: -0.8335522264242172, accuracy: 89.84%
# Epoch 418
# 	train - loss: 1.96e-01
# 	val - loss: -0.8338853269815445, accuracy: 89.84%
# Epoch 419
# 	train - loss: 1.95e-01
# 	val - loss: -0.8342200368642807, accuracy: 89.84%
# Epoch 420
# 	train - loss: 1.94e-01
# 	val - loss: -0.8345593214035034, accuracy: 89.84%
# Epoch 421
# 	train - loss: 1.94e-01
# 	val - loss: -0.834883451461792, accuracy: 90.23%
# Epoch 422
# 	train - loss: 1.93e-01
# 	val - loss: -0.8352238833904266, accuracy: 90.23%
# Epoch 423
# 	train - loss: 1.93e-01
# 	val - loss: -0.8355359435081482, accuracy: 90.23%
# Epoch 424
# 	train - loss: 1.92e-01
# 	val - loss: -0.8358769565820694, accuracy: 90.23%
# Epoch 425
# 	train - loss: 1.91e-01
# 	val - loss: -0.8361895233392715, accuracy: 90.23%
# Epoch 426
# 	train - loss: 1.91e-01
# 	val - loss: -0.8365186303853989, accuracy: 90.23%
# Epoch 427
# 	train - loss: 1.90e-01
# 	val - loss: -0.8368313908576965, accuracy: 90.23%
# Epoch 428
# 	train - loss: 1.90e-01
# 	val - loss: -0.8371805399656296, accuracy: 90.23%
# Epoch 429
# 	train - loss: 1.89e-01
# 	val - loss: -0.8374891579151154, accuracy: 90.23%
# Epoch 430
# 	train - loss: 1.89e-01
# 	val - loss: -0.8378032445907593, accuracy: 90.23%
# Epoch 431
# 	train - loss: 1.88e-01
# 	val - loss: -0.8381423801183701, accuracy: 90.23%
# Epoch 432
# 	train - loss: 1.87e-01
# 	val - loss: -0.8384469598531723, accuracy: 90.23%
# Epoch 433
# 	train - loss: 1.87e-01
# 	val - loss: -0.8387574851512909, accuracy: 90.23%
# Epoch 434
# 	train - loss: 1.86e-01
# 	val - loss: -0.8390804529190063, accuracy: 90.62%
# Epoch 435
# 	train - loss: 1.86e-01
# 	val - loss: -0.8393991738557816, accuracy: 90.62%
# Epoch 436
# 	train - loss: 1.85e-01
# 	val - loss: -0.8397251665592194, accuracy: 91.02%
# Epoch 437
# 	train - loss: 1.85e-01
# 	val - loss: -0.8400181829929352, accuracy: 91.02%
# Epoch 438
# 	train - loss: 1.84e-01
# 	val - loss: -0.8403446078300476, accuracy: 91.02%
# Epoch 439
# 	train - loss: 1.84e-01
# 	val - loss: -0.840652346611023, accuracy: 91.02%
# Epoch 440
# 	train - loss: 1.83e-01
# 	val - loss: -0.8409721702337265, accuracy: 91.02%
# Epoch 441
# 	train - loss: 1.83e-01
# 	val - loss: -0.8412738144397736, accuracy: 91.02%
# Epoch 442
# 	train - loss: 1.82e-01
# 	val - loss: -0.8415769040584564, accuracy: 91.02%
# Epoch 443
# 	train - loss: 1.81e-01
# 	val - loss: -0.8418869078159332, accuracy: 91.02%
# Epoch 444
# 	train - loss: 1.81e-01
# 	val - loss: -0.8421908468008041, accuracy: 91.02%
# Epoch 445
# 	train - loss: 1.80e-01
# 	val - loss: -0.8424765467643738, accuracy: 91.02%
# Epoch 446
# 	train - loss: 1.80e-01
# 	val - loss: -0.842789962887764, accuracy: 91.02%
# Epoch 447
# 	train - loss: 1.79e-01
# 	val - loss: -0.8430939465761185, accuracy: 91.02%
# Epoch 448
# 	train - loss: 1.79e-01
# 	val - loss: -0.8433871120214462, accuracy: 91.02%
# Epoch 449
# 	train - loss: 1.78e-01
# 	val - loss: -0.8436703383922577, accuracy: 91.02%
# Epoch 450
# 	train - loss: 1.78e-01
# 	val - loss: -0.8439546823501587, accuracy: 91.02%
# Epoch 451
# 	train - loss: 1.77e-01
# 	val - loss: -0.8442506343126297, accuracy: 91.02%
# Epoch 452
# 	train - loss: 1.77e-01
# 	val - loss: -0.8445500731468201, accuracy: 91.02%
# Epoch 453
# 	train - loss: 1.76e-01
# 	val - loss: -0.8448359072208405, accuracy: 91.02%
# Epoch 454
# 	train - loss: 1.76e-01
# 	val - loss: -0.8451084792613983, accuracy: 91.02%
# Epoch 455
# 	train - loss: 1.75e-01
# 	val - loss: -0.8454029262065887, accuracy: 91.02%
# Epoch 456
# 	train - loss: 1.75e-01
# 	val - loss: -0.8456919938325882, accuracy: 91.02%
# Epoch 457
# 	train - loss: 1.74e-01
# 	val - loss: -0.8459766060113907, accuracy: 91.02%
# Epoch 458
# 	train - loss: 1.74e-01
# 	val - loss: -0.8462527245283127, accuracy: 91.02%
# Epoch 459
# 	train - loss: 1.73e-01
# 	val - loss: -0.8465293794870377, accuracy: 91.02%
# Epoch 460
# 	train - loss: 1.73e-01
# 	val - loss: -0.8468177318572998, accuracy: 91.02%
# Epoch 461
# 	train - loss: 1.72e-01
# 	val - loss: -0.8470998555421829, accuracy: 91.02%
# Epoch 462
# 	train - loss: 1.72e-01
# 	val - loss: -0.8473721742630005, accuracy: 91.02%
# Epoch 463
# 	train - loss: 1.71e-01
# 	val - loss: -0.8476441353559494, accuracy: 91.02%
# Epoch 464
# 	train - loss: 1.71e-01
# 	val - loss: -0.8479162752628326, accuracy: 91.41%
# Epoch 465
# 	train - loss: 1.71e-01
# 	val - loss: -0.848192423582077, accuracy: 91.41%
# Epoch 466
# 	train - loss: 1.70e-01
# 	val - loss: -0.8484624624252319, accuracy: 91.41%
# Epoch 467
# 	train - loss: 1.70e-01
# 	val - loss: -0.8487327396869659, accuracy: 91.41%
# Epoch 468
# 	train - loss: 1.69e-01
# 	val - loss: -0.8490026146173477, accuracy: 91.41%
# Epoch 469
# 	train - loss: 1.69e-01
# 	val - loss: -0.8492707461118698, accuracy: 91.41%
# Epoch 470
# 	train - loss: 1.68e-01
# 	val - loss: -0.8495237082242966, accuracy: 91.41%
# Epoch 471
# 	train - loss: 1.68e-01
# 	val - loss: -0.8497993499040604, accuracy: 91.41%
# Epoch 472
# 	train - loss: 1.67e-01
# 	val - loss: -0.850055992603302, accuracy: 91.41%
# Epoch 473
# 	train - loss: 1.67e-01
# 	val - loss: -0.8503099232912064, accuracy: 91.41%
# Epoch 474
# 	train - loss: 1.66e-01
# 	val - loss: -0.8505769968032837, accuracy: 91.41%
# Epoch 475
# 	train - loss: 1.66e-01
# 	val - loss: -0.8508282005786896, accuracy: 91.41%
# Epoch 476
# 	train - loss: 1.66e-01
# 	val - loss: -0.8510847091674805, accuracy: 91.41%
# Epoch 477
# 	train - loss: 1.65e-01
# 	val - loss: -0.8513476997613907, accuracy: 91.41%
# Epoch 478
# 	train - loss: 1.65e-01
# 	val - loss: -0.8516059964895248, accuracy: 91.41%
# Epoch 479
# 	train - loss: 1.64e-01
# 	val - loss: -0.8518536388874054, accuracy: 91.41%
# Epoch 480
# 	train - loss: 1.64e-01
# 	val - loss: -0.8521164059638977, accuracy: 91.41%
# Epoch 481
# 	train - loss: 1.63e-01
# 	val - loss: -0.8523545116186142, accuracy: 91.41%
# Epoch 482
# 	train - loss: 1.63e-01
# 	val - loss: -0.8526088744401932, accuracy: 91.41%
# Epoch 483
# 	train - loss: 1.63e-01
# 	val - loss: -0.8528481274843216, accuracy: 91.41%
# Epoch 484
# 	train - loss: 1.62e-01
# 	val - loss: -0.853093758225441, accuracy: 91.41%
# Epoch 485
# 	train - loss: 1.62e-01
# 	val - loss: -0.8533454686403275, accuracy: 91.41%
# Epoch 486
# 	train - loss: 1.61e-01
# 	val - loss: -0.8536090701818466, accuracy: 91.41%
# Epoch 487
# 	train - loss: 1.61e-01
# 	val - loss: -0.8538442254066467, accuracy: 91.41%
# Epoch 488
# 	train - loss: 1.61e-01
# 	val - loss: -0.854087233543396, accuracy: 91.41%
# Epoch 489
# 	train - loss: 1.60e-01
# 	val - loss: -0.8543310016393661, accuracy: 91.41%
# Epoch 490
# 	train - loss: 1.60e-01
# 	val - loss: -0.8545779883861542, accuracy: 91.80%
# Epoch 491
# 	train - loss: 1.59e-01
# 	val - loss: -0.8548158556222916, accuracy: 91.80%
# Epoch 492
# 	train - loss: 1.59e-01
# 	val - loss: -0.8550577759742737, accuracy: 91.80%
# Epoch 493
# 	train - loss: 1.59e-01
# 	val - loss: -0.8553097248077393, accuracy: 91.80%
# Epoch 494
# 	train - loss: 1.58e-01
# 	val - loss: -0.8555387705564499, accuracy: 91.80%
# Epoch 495
# 	train - loss: 1.58e-01
# 	val - loss: -0.8557758331298828, accuracy: 91.80%
# Epoch 496
# 	train - loss: 1.57e-01
# 	val - loss: -0.8560081720352173, accuracy: 91.80%
# Epoch 497
# 	train - loss: 1.57e-01
# 	val - loss: -0.8562546521425247, accuracy: 91.80%
# Epoch 498
# 	train - loss: 1.57e-01
# 	val - loss: -0.856478825211525, accuracy: 91.80%
# Epoch 499
# 	train - loss: 1.56e-01
# 	val - loss: -0.8567139059305191, accuracy: 91.80%
# Epoch 500
# 	train - loss: 1.56e-01
# 	val - loss: -0.8569522947072983, accuracy: 91.80%
# Epoch 501
# 	train - loss: 1.55e-01
# 	val - loss: -0.8571940809488297, accuracy: 91.80%
# Epoch 502
# 	train - loss: 1.55e-01
# 	val - loss: -0.8574251383543015, accuracy: 91.80%
# Epoch 503
# 	train - loss: 1.55e-01
# 	val - loss: -0.8576303720474243, accuracy: 91.80%
# Epoch 504
# 	train - loss: 1.54e-01
# 	val - loss: -0.8578628152608871, accuracy: 91.80%
# Epoch 505
# 	train - loss: 1.54e-01
# 	val - loss: -0.8580964207649231, accuracy: 91.80%
# Epoch 506
# 	train - loss: 1.54e-01
# 	val - loss: -0.8583226352930069, accuracy: 91.80%
# Epoch 507
# 	train - loss: 1.53e-01
# 	val - loss: -0.8585607409477234, accuracy: 91.80%
# Epoch 508
# 	train - loss: 1.53e-01
# 	val - loss: -0.8587628751993179, accuracy: 91.80%
# Epoch 509
# 	train - loss: 1.52e-01
# 	val - loss: -0.8589989840984344, accuracy: 91.80%
# Epoch 510
# 	train - loss: 1.52e-01
# 	val - loss: -0.8592159152030945, accuracy: 91.80%
# Epoch 511
# 	train - loss: 1.52e-01
# 	val - loss: -0.8594525307416916, accuracy: 91.80%
# Epoch 512
# 	train - loss: 1.51e-01
# 	val - loss: -0.8596544861793518, accuracy: 91.80%
# Epoch 513
# 	train - loss: 1.51e-01
# 	val - loss: -0.8598740994930267, accuracy: 91.80%
# Epoch 514
# 	train - loss: 1.51e-01
# 	val - loss: -0.860094279050827, accuracy: 91.80%
# Epoch 515
# 	train - loss: 1.50e-01
# 	val - loss: -0.8603163212537766, accuracy: 91.80%
# Epoch 516
# 	train - loss: 1.50e-01
# 	val - loss: -0.8605363965034485, accuracy: 91.80%
# Epoch 517
# 	train - loss: 1.50e-01
# 	val - loss: -0.8607493788003922, accuracy: 91.80%
# Epoch 518
# 	train - loss: 1.49e-01
# 	val - loss: -0.8609609007835388, accuracy: 91.80%
# Epoch 519
# 	train - loss: 1.49e-01
# 	val - loss: -0.8611674010753632, accuracy: 91.80%
# Epoch 520
# 	train - loss: 1.49e-01
# 	val - loss: -0.8613868653774261, accuracy: 91.80%
# Epoch 521
# 	train - loss: 1.48e-01
# 	val - loss: -0.8615932762622833, accuracy: 91.80%
# Epoch 522
# 	train - loss: 1.48e-01
# 	val - loss: -0.8617920279502869, accuracy: 91.80%
# Epoch 523
# 	train - loss: 1.48e-01
# 	val - loss: -0.8620161861181259, accuracy: 91.80%
# Epoch 524
# 	train - loss: 1.47e-01
# 	val - loss: -0.8622185736894608, accuracy: 91.80%
# Epoch 525
# 	train - loss: 1.47e-01
# 	val - loss: -0.8624129295349121, accuracy: 91.80%
# Epoch 526
# 	train - loss: 1.47e-01
# 	val - loss: -0.862623542547226, accuracy: 91.80%
# Epoch 527
# 	train - loss: 1.46e-01
# 	val - loss: -0.8628321886062622, accuracy: 91.80%
# Epoch 528
# 	train - loss: 1.46e-01
# 	val - loss: -0.8630445748567581, accuracy: 91.80%
# Epoch 529
# 	train - loss: 1.46e-01
# 	val - loss: -0.8632367253303528, accuracy: 91.80%
# Epoch 530
# 	train - loss: 1.45e-01
# 	val - loss: -0.8634358793497086, accuracy: 91.80%
# Epoch 531
# 	train - loss: 1.45e-01
# 	val - loss: -0.8636504709720612, accuracy: 91.80%
# Epoch 532
# 	train - loss: 1.45e-01
# 	val - loss: -0.8638427406549454, accuracy: 91.80%
# Epoch 533
# 	train - loss: 1.44e-01
# 	val - loss: -0.8640450686216354, accuracy: 91.80%
# Epoch 534
# 	train - loss: 1.44e-01
# 	val - loss: -0.8642497509717941, accuracy: 91.80%
# Epoch 535
# 	train - loss: 1.44e-01
# 	val - loss: -0.8644421249628067, accuracy: 91.80%
# Epoch 536
# 	train - loss: 1.43e-01
# 	val - loss: -0.8646387010812759, accuracy: 91.80%
# Epoch 537
# 	train - loss: 1.43e-01
# 	val - loss: -0.8648415207862854, accuracy: 91.80%
# Epoch 538
# 	train - loss: 1.43e-01
# 	val - loss: -0.8650351315736771, accuracy: 91.80%
# Epoch 539
# 	train - loss: 1.42e-01
# 	val - loss: -0.8652456104755402, accuracy: 91.80%
# Epoch 540
# 	train - loss: 1.42e-01
# 	val - loss: -0.8654401153326035, accuracy: 91.80%
# Epoch 541
# 	train - loss: 1.42e-01
# 	val - loss: -0.8656326085329056, accuracy: 91.80%
# Epoch 542
# 	train - loss: 1.41e-01
# 	val - loss: -0.8658215403556824, accuracy: 91.80%
# Epoch 543
# 	train - loss: 1.41e-01
# 	val - loss: -0.8660127371549606, accuracy: 91.80%
# Epoch 544
# 	train - loss: 1.41e-01
# 	val - loss: -0.8662005215883255, accuracy: 91.80%
# Epoch 545
# 	train - loss: 1.41e-01
# 	val - loss: -0.8664068281650543, accuracy: 91.80%
# Epoch 546
# 	train - loss: 1.40e-01
# 	val - loss: -0.8665829300880432, accuracy: 91.80%
# Epoch 547
# 	train - loss: 1.40e-01
# 	val - loss: -0.8667858242988586, accuracy: 91.80%
# Epoch 548
# 	train - loss: 1.40e-01
# 	val - loss: -0.8669809699058533, accuracy: 91.80%
# Epoch 549
# 	train - loss: 1.39e-01
# 	val - loss: -0.8671595454216003, accuracy: 91.80%
# Epoch 550
# 	train - loss: 1.39e-01
# 	val - loss: -0.8673547059297562, accuracy: 91.80%
# Epoch 551
# 	train - loss: 1.39e-01
# 	val - loss: -0.8675406128168106, accuracy: 91.80%
# Epoch 552
# 	train - loss: 1.38e-01
# 	val - loss: -0.8677266985177994, accuracy: 91.80%
# Epoch 553
# 	train - loss: 1.38e-01
# 	val - loss: -0.8679111301898956, accuracy: 91.80%
# Epoch 554
# 	train - loss: 1.38e-01
# 	val - loss: -0.8680959343910217, accuracy: 91.80%
# Epoch 555
# 	train - loss: 1.38e-01
# 	val - loss: -0.8682857006788254, accuracy: 91.80%
# Epoch 556
# 	train - loss: 1.37e-01
# 	val - loss: -0.8684661388397217, accuracy: 91.80%
# Epoch 557
# 	train - loss: 1.37e-01
# 	val - loss: -0.8686476498842239, accuracy: 91.80%
# Epoch 558
# 	train - loss: 1.37e-01
# 	val - loss: -0.8688299506902695, accuracy: 91.80%
# Epoch 559
# 	train - loss: 1.36e-01
# 	val - loss: -0.8690100610256195, accuracy: 91.80%
# Epoch 560
# 	train - loss: 1.36e-01
# 	val - loss: -0.8691949844360352, accuracy: 91.80%
# Epoch 561
# 	train - loss: 1.36e-01
# 	val - loss: -0.869385227560997, accuracy: 91.80%
# Epoch 562
# 	train - loss: 1.36e-01
# 	val - loss: -0.8695619255304337, accuracy: 91.80%
# Epoch 563
# 	train - loss: 1.35e-01
# 	val - loss: -0.8697227537631989, accuracy: 91.80%
# Epoch 564
# 	train - loss: 1.35e-01
# 	val - loss: -0.8699025511741638, accuracy: 91.80%
# Epoch 565
# 	train - loss: 1.35e-01
# ...
# Epoch 9814
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708201885223389, accuracy: 98.83%
# Epoch 9815
# 	train - loss: 3.92e-02
# 	val - loss: -0.970790684223175, accuracy: 98.83%
# Epoch 9816
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708030074834824, accuracy: 98.83%
# Epoch 9817
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708022028207779, accuracy: 98.83%
# Epoch 9818
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708084315061569, accuracy: 98.83%
# Epoch 9819
# 	train - loss: 3.93e-02
# 	val - loss: -0.9707845002412796, accuracy: 98.83%
# Epoch 9820
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707826673984528, accuracy: 98.83%
# Epoch 9821
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708008766174316, accuracy: 98.83%
# Epoch 9822
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707800447940826, accuracy: 98.83%
# Epoch 9823
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707749336957932, accuracy: 98.83%
# Epoch 9824
# 	train - loss: 3.92e-02
# 	val - loss: -0.97077377140522, accuracy: 98.83%
# Epoch 9825
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707857966423035, accuracy: 98.83%
# Epoch 9826
# 	train - loss: 3.92e-02
# 	val - loss: -0.970807820558548, accuracy: 98.83%
# Epoch 9827
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707909226417542, accuracy: 98.83%
# Epoch 9828
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707995057106018, accuracy: 98.83%
# Epoch 9829
# 	train - loss: 3.92e-02
# 	val - loss: -0.970797210931778, accuracy: 98.83%
# Epoch 9830
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707927703857422, accuracy: 98.83%
# Epoch 9831
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707907289266586, accuracy: 98.83%
# Epoch 9832
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707841128110886, accuracy: 98.83%
# Epoch 9833
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708041101694107, accuracy: 98.83%
# Epoch 9834
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707954525947571, accuracy: 98.83%
# Epoch 9835
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708222448825836, accuracy: 98.83%
# Epoch 9836
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707875102758408, accuracy: 98.83%
# Epoch 9837
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708017706871033, accuracy: 98.83%
# Epoch 9838
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708042740821838, accuracy: 98.83%
# Epoch 9839
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708216637372971, accuracy: 98.83%
# Epoch 9840
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707918763160706, accuracy: 98.83%
# Epoch 9841
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708032608032227, accuracy: 98.83%
# Epoch 9842
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708017557859421, accuracy: 98.83%
# Epoch 9843
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707763493061066, accuracy: 98.83%
# Epoch 9844
# 	train - loss: 3.92e-02
# 	val - loss: -0.970782607793808, accuracy: 98.83%
# Epoch 9845
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707819074392319, accuracy: 98.83%
# Epoch 9846
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707859456539154, accuracy: 98.83%
# Epoch 9847
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708157479763031, accuracy: 98.83%
# Epoch 9848
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707909524440765, accuracy: 98.83%
# Epoch 9849
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707777947187424, accuracy: 98.83%
# Epoch 9850
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707697182893753, accuracy: 98.83%
# Epoch 9851
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707975834608078, accuracy: 98.83%
# Epoch 9852
# 	train - loss: 3.92e-02
# 	val - loss: -0.970776304602623, accuracy: 98.83%
# Epoch 9853
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707821160554886, accuracy: 98.83%
# Epoch 9854
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707993566989899, accuracy: 98.83%
# Epoch 9855
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707927256822586, accuracy: 98.83%
# Epoch 9856
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707827866077423, accuracy: 98.83%
# Epoch 9857
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707801938056946, accuracy: 98.83%
# Epoch 9858
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707676321268082, accuracy: 98.83%
# Epoch 9859
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707885235548019, accuracy: 98.83%
# Epoch 9860
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708016216754913, accuracy: 98.83%
# Epoch 9861
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707996696233749, accuracy: 98.83%
# Epoch 9862
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707864671945572, accuracy: 98.83%
# Epoch 9863
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707803279161453, accuracy: 98.83%
# Epoch 9864
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707954674959183, accuracy: 98.83%
# Epoch 9865
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707903563976288, accuracy: 98.83%
# Epoch 9866
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707794636487961, accuracy: 98.83%
# Epoch 9867
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707776606082916, accuracy: 98.83%
# Epoch 9868
# 	train - loss: 3.92e-02
# 	val - loss: -0.97079798579216, accuracy: 98.83%
# Epoch 9869
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708147495985031, accuracy: 98.83%
# Epoch 9870
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707817584276199, accuracy: 98.83%
# Epoch 9871
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707796722650528, accuracy: 98.83%
# Epoch 9872
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707991927862167, accuracy: 98.83%
# Epoch 9873
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707955867052078, accuracy: 98.83%
# Epoch 9874
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707823097705841, accuracy: 98.83%
# Epoch 9875
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707991480827332, accuracy: 98.83%
# Epoch 9876
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708200246095657, accuracy: 98.83%
# Epoch 9877
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707863181829453, accuracy: 98.83%
# Epoch 9878
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707986116409302, accuracy: 98.83%
# Epoch 9879
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707996249198914, accuracy: 98.83%
# Epoch 9880
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708064496517181, accuracy: 98.83%
# Epoch 9881
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708173871040344, accuracy: 98.83%
# Epoch 9882
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708008021116257, accuracy: 98.83%
# Epoch 9883
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708003848791122, accuracy: 98.83%
# Epoch 9884
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707944989204407, accuracy: 98.83%
# Epoch 9885
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708044528961182, accuracy: 98.83%
# Epoch 9886
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708121120929718, accuracy: 98.83%
# Epoch 9887
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707917273044586, accuracy: 98.83%
# Epoch 9888
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708072543144226, accuracy: 98.83%
# Epoch 9889
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708238691091537, accuracy: 98.83%
# Epoch 9890
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708141386508942, accuracy: 98.83%
# Epoch 9891
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707913100719452, accuracy: 98.83%
# Epoch 9892
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707870036363602, accuracy: 98.83%
# Epoch 9893
# 	train - loss: 3.92e-02
# 	val - loss: -0.970809817314148, accuracy: 98.83%
# Epoch 9894
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707896560430527, accuracy: 98.83%
# Epoch 9895
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707764089107513, accuracy: 98.83%
# Epoch 9896
# 	train - loss: 3.92e-02
# 	val - loss: -0.970778152346611, accuracy: 98.83%
# Epoch 9897
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708117246627808, accuracy: 98.83%
# Epoch 9898
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707916080951691, accuracy: 98.83%
# Epoch 9899
# 	train - loss: 3.91e-02
# 	val - loss: -0.9708030223846436, accuracy: 98.83%
# Epoch 9900
# 	train - loss: 3.91e-02
# 	val - loss: -0.9708280861377716, accuracy: 98.83%
# Epoch 9901
# 	train - loss: 3.92e-02
# 	val - loss: -0.970775917172432, accuracy: 98.83%
# Epoch 9902
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708056598901749, accuracy: 98.83%
# Epoch 9903
# 	train - loss: 3.92e-02
# 	val - loss: -0.9708217531442642, accuracy: 98.83%
# Epoch 9904
# 	train - loss: 3.91e-02
# 	val - loss: -0.9708054065704346, accuracy: 98.83%
# Epoch 9905
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707852900028229, accuracy: 98.83%
# Epoch 9906
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707961827516556, accuracy: 98.83%
# Epoch 9907
# 	train - loss: 3.92e-02
# 	val - loss: -0.9707896113395691, accuracy: 98.83%
# Epoch 9908
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707844853401184, accuracy: 98.83%
# Epoch 9909
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707922339439392, accuracy: 98.83%
# Epoch 9910
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707893878221512, accuracy: 98.83%
# Epoch 9911
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707817584276199, accuracy: 98.83%
# Epoch 9912
# 	train - loss: 3.91e-02
# 	val - loss: -0.970782458782196, accuracy: 98.83%
# Epoch 9913
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707957953214645, accuracy: 98.83%
# Epoch 9914
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707905948162079, accuracy: 98.83%
# Epoch 9915
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707647264003754, accuracy: 98.83%
# Epoch 9916
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707814157009125, accuracy: 98.83%
# Epoch 9917
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707687795162201, accuracy: 98.83%
# Epoch 9918
# 	train - loss: 3.91e-02
# 	val - loss: -0.9708065241575241, accuracy: 98.83%
# Epoch 9919
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707857668399811, accuracy: 98.83%
# Epoch 9920
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707659333944321, accuracy: 98.83%
# Epoch 9921
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707724750041962, accuracy: 98.83%
# Epoch 9922
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707697182893753, accuracy: 98.83%
# Epoch 9923
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707867950201035, accuracy: 98.83%
# Epoch 9924
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707953333854675, accuracy: 98.83%
# Epoch 9925
# 	train - loss: 3.91e-02
# 	val - loss: -0.970758244395256, accuracy: 98.83%
# Epoch 9926
# 	train - loss: 3.91e-02
# 	val - loss: -0.970763549208641, accuracy: 98.83%
# Epoch 9927
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707707464694977, accuracy: 98.83%
# Epoch 9928
# 	train - loss: 3.91e-02
# 	val - loss: -0.97080497443676, accuracy: 98.83%
# Epoch 9929
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707828909158707, accuracy: 98.83%
# Epoch 9930
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707807451486588, accuracy: 98.83%
# Epoch 9931
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707595109939575, accuracy: 98.83%
# Epoch 9932
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707924723625183, accuracy: 98.83%
# Epoch 9933
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707782715559006, accuracy: 98.83%
# Epoch 9934
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707936644554138, accuracy: 98.83%
# Epoch 9935
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707714468240738, accuracy: 98.83%
# Epoch 9936
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707855731248856, accuracy: 98.83%
# Epoch 9937
# 	train - loss: 3.91e-02
# 	val - loss: -0.9708070158958435, accuracy: 98.83%
# Epoch 9938
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707764834165573, accuracy: 98.83%
# Epoch 9939
# 	train - loss: 3.91e-02
# 	val - loss: -0.970796138048172, accuracy: 98.83%
# Epoch 9940
# 	train - loss: 3.91e-02
# 	val - loss: -0.9708034247159958, accuracy: 98.83%
# Epoch 9941
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707906693220139, accuracy: 98.83%
# Epoch 9942
# 	train - loss: 3.91e-02
# 	val - loss: -0.970805212855339, accuracy: 98.83%
# Epoch 9943
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707572758197784, accuracy: 98.83%
# Epoch 9944
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707693606615067, accuracy: 98.83%
# Epoch 9945
# 	train - loss: 3.91e-02
# 	val - loss: -0.970761239528656, accuracy: 98.83%
# Epoch 9946
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707853198051453, accuracy: 98.83%
# Epoch 9947
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707585275173187, accuracy: 98.83%
# Epoch 9948
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707678854465485, accuracy: 98.83%
# Epoch 9949
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707793593406677, accuracy: 98.83%
# Epoch 9950
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707795679569244, accuracy: 98.83%
# Epoch 9951
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707721471786499, accuracy: 98.83%
# Epoch 9952
# 	train - loss: 3.91e-02
# 	val - loss: -0.9708009362220764, accuracy: 98.83%
# Epoch 9953
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707804024219513, accuracy: 98.83%
# Epoch 9954
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707624465227127, accuracy: 98.83%
# Epoch 9955
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707757085561752, accuracy: 98.83%
# Epoch 9956
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707659482955933, accuracy: 98.83%
# Epoch 9957
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707716256380081, accuracy: 98.83%
# Epoch 9958
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707863032817841, accuracy: 98.83%
# Epoch 9959
# 	train - loss: 3.91e-02
# 	val - loss: -0.970763772726059, accuracy: 98.83%
# Epoch 9960
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707702994346619, accuracy: 98.83%
# Epoch 9961
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707808047533035, accuracy: 98.83%
# Epoch 9962
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707835465669632, accuracy: 98.83%
# Epoch 9963
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707894921302795, accuracy: 98.83%
# Epoch 9964
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707815200090408, accuracy: 98.83%
# Epoch 9965
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707735776901245, accuracy: 98.83%
# Epoch 9966
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707846790552139, accuracy: 98.83%
# Epoch 9967
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707727581262589, accuracy: 98.83%
# Epoch 9968
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707583636045456, accuracy: 98.83%
# Epoch 9969
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707685858011246, accuracy: 98.83%
# Epoch 9970
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707876443862915, accuracy: 98.83%
# Epoch 9971
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707760810852051, accuracy: 98.83%
# Epoch 9972
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707928448915482, accuracy: 98.83%
# Epoch 9973
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707667231559753, accuracy: 98.83%
# Epoch 9974
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707797765731812, accuracy: 98.83%
# Epoch 9975
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707854837179184, accuracy: 98.83%
# Epoch 9976
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707836657762527, accuracy: 98.83%
# Epoch 9977
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707575291395187, accuracy: 98.83%
# Epoch 9978
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707633256912231, accuracy: 98.83%
# Epoch 9979
# 	train - loss: 3.91e-02
# 	val - loss: -0.9708076119422913, accuracy: 98.83%
# Epoch 9980
# 	train - loss: 3.91e-02
# 	val - loss: -0.970798060297966, accuracy: 98.83%
# Epoch 9981
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707715064287186, accuracy: 98.83%
# Epoch 9982
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707852452993393, accuracy: 98.83%
# Epoch 9983
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707929342985153, accuracy: 98.83%
# Epoch 9984
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707888066768646, accuracy: 98.83%
# Epoch 9985
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707918912172318, accuracy: 98.83%
# Epoch 9986
# 	train - loss: 3.91e-02
# 	val - loss: -0.9708007574081421, accuracy: 98.83%
# Epoch 9987
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707905501127243, accuracy: 98.83%
# Epoch 9988
# 	train - loss: 3.91e-02
# 	val - loss: -0.970774844288826, accuracy: 98.83%
# Epoch 9989
# 	train - loss: 3.91e-02
# 	val - loss: -0.970772996544838, accuracy: 98.83%
# Epoch 9990
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707940071821213, accuracy: 98.83%
# Epoch 9991
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707751274108887, accuracy: 98.83%
# Epoch 9992
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707793295383453, accuracy: 98.83%
# Epoch 9993
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707528650760651, accuracy: 98.83%
# Epoch 9994
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707635194063187, accuracy: 98.83%
# Epoch 9995
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707728028297424, accuracy: 98.83%
# Epoch 9996
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707711040973663, accuracy: 98.83%
# Epoch 9997
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707879573106766, accuracy: 98.83%
# Epoch 9998
# 	train - loss: 3.91e-02
# 	val - loss: -0.9707812368869781, accuracy: 98.83%
# Epoch 9999
# 	train - loss: 3.90e-02
# 	val - loss: -0.9707460850477219, accuracy: 98.83%
